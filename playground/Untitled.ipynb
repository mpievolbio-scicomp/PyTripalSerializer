# %%
# %load_ext autoreload

# %autoreload 2



from rdflib import Graph, URIRef, Literal, BNode
from pprint import pprint
import logging

logging.basicConfig(level=logging.WARNING)

# %%
from tripser.tripser import *

# %%
parser = RecursiveJSONLDParser('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900', graph=Graph(),
                              client='127.0.0.1:8786')

# %%
parser.parse()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 parser.parse()
#
# File ~/Repositories/pytripalserializer/tripser/tripser.py:214, in RecursiveJSONLDParser.parse(self)
#     211 parsed_pages = self.parsed_pages
#     212 futures = self.client.map(recursively_add, tasks, [graph], [parsed_pages])
# --> 214 tasks, graphs, parsed_books = self.client.gather(futures)
#     216 for graph in graphs:
#     217     self.graph += graph
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
graph = parser.graph

# %%
len(graph)
# Out:
# 0

# %%
parsed_pages = parser.parsed_pages

# %%
tasks = [parser.entry_point]

# %%
parser.client
# Out:
# <Client: 'tcp://172.16.5.80:8786' processes=2 threads=16, memory=30.71 GiB>

# %%
parser.client.restart()
# Out:
# <Client: 'tcp://172.16.5.80:8786' processes=0 threads=0, memory=0 B>

# %%
parser.client.m
