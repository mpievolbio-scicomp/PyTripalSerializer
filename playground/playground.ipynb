# %%
# %load_ext autoreload

# %autoreload 2



from rdflib import Graph, URIRef, Literal, BNode
from pprint import pprint
import logging

logging.basicConfig(level=logging.WARNING)

import sys
sys.path.insert(0,'../tripser')

from tripser import *

parser = RecursiveJSONLDParser('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900', graph=Graph())

# %%
# %%time
parser.parse()
# Out:
# INFO:tripser:1 tasks complete, 0 tasks to do
# INFO:tripser:2 tasks complete, 8 tasks to do
# INFO:tripser:3 tasks complete, 7 tasks to do
# INFO:tripser:4 tasks complete, 6 tasks to do
# INFO:tripser:5 tasks complete, 5 tasks to do
# INFO:tripser:6 tasks complete, 4 tasks to do
# INFO:tripser:7 tasks complete, 4 tasks to do
# INFO:tripser:8 tasks complete, 6 tasks to do
# INFO:tripser:9 tasks complete, 9 tasks to do
# INFO:tripser:10 tasks complete, 9 tasks to do
# INFO:tripser:11 tasks complete, 9 tasks to do
# INFO:tripser:12 tasks complete, 8 tasks to do
# INFO:tripser:13 tasks complete, 7 tasks to do
# INFO:tripser:14 tasks complete, 16 tasks to do
# INFO:tripser:15 tasks complete, 15 tasks to do
# INFO:tripser:16 tasks complete, 14 tasks to do
# INFO:tripser:17 tasks complete, 14 tasks to do
# INFO:tripser:18 tasks complete, 13 tasks to do
# INFO:tripser:19 tasks complete, 12 tasks to do
# INFO:tripser:20 tasks complete, 11 tasks to do
# ...

# %%
parser.graph.print()
# Out:
# @prefix cds: <http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/> .
# @prefix edam: <http://edamontology.org/> .
# @prefix exon: <http://pflu.evolbio.mpg.de/web-services/content/v0.1/Exon/> .
# @prefix gene: <http://pflu.evolbio.mpg.de/web-services/content/v0.1/Gene/> .
# @prefix hydra: <http://www.w3.org/ns/hydra/core#> .
# @prefix mrna: <http://pflu.evolbio.mpg.de/web-services/content/v0.1/mRNA/> .
# @prefix ncbitax: <https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=> .
# @prefix obo: <http://purl.obolibrary.org/obo/> .
# @prefix organism: <http://pflu.evolbio.mpg.de/web-services/content/v0.1/Organism/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix so: <http://www.sequenceontology.org/browser/current_svn/term/SO:> .
# @prefix ssr: <http://semanticscience.org/resource/> .
# @prefix tripal3: <http://pflu.evolbio.mpg.de/cv/lookup/local/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ...

# %%
g = get_graph("http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS")
# Out:
# DEBUG:tripser:get_graph(graph=http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS)
# DEBUG:tripser:Setting up empty graph.
# DEBUG:tripser:Attempting to parse http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): pflu.evolbio.mpg.de:80
# DEBUG:urllib3.connectionpool:http://pflu.evolbio.mpg.de:80 "GET /web-services/content/v0.1/CDS HTTP/1.1" 200 5150
# DEBUG:tripser:Parsed 105 terms.

# %%
isinstance(g, Collection)
# Out:
# False

# %%
from rdflib.collection import Collection

# %%
Collection?
# Out:
# Init signature: Collection(graph, uri, seq=[])
# Docstring:
# See "Emulating container types":
# https://docs.python.org/reference/datamodel.html#emulating-container-types
#
# >>> from rdflib.graph import Graph
# >>> from pprint import pprint
# >>> listName = BNode()
# >>> g = Graph('Memory')
# >>> listItem1 = BNode()
# >>> listItem2 = BNode()
# >>> g.add((listName, RDF.first, Literal(1))) # doctest: +ELLIPSIS
# <Graph identifier=... (<class 'rdflib.graph.Graph'>)>
# >>> g.add((listName, RDF.rest, listItem1)) # doctest: +ELLIPSIS
# <Graph identifier=... (<class 'rdflib.graph.Graph'>)>
# >>> g.add((listItem1, RDF.first, Literal(2))) # doctest: +ELLIPSIS
# <Graph identifier=... (<class 'rdflib.graph.Graph'>)>
# >>> g.add((listItem1, RDF.rest, listItem2)) # doctest: +ELLIPSIS
# <Graph identifier=... (<class 'rdflib.graph.Graph'>)>
# >>> g.add((listItem2, RDF.rest, RDF.nil)) # doctest: +ELLIPSIS
# <Graph identifier=... (<class 'rdflib.graph.Graph'>)>
# ...

# %%
for s in g.subjects():
    pprint(s)
# Out:
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11845')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11847')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11859')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11848')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11858')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11864')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11858')
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11860')
# ...

# %%
for term in g:
    pprint(term)
# Out:
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS'),
#  rdflib.term.URIRef('http://www.w3.org/ns/hydra/core#member'),
#  rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11852'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11845'),
#  rdflib.term.URIRef('https://schema.org/ItemPage'),
#  rdflib.term.Literal('http://pflu.evolbio.mpg.de/bio_data/11845'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11847'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('CDS:PFLU_0003-0'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11859'),
#  rdflib.term.URIRef('https://schema.org/ItemPage'),
#  rdflib.term.Literal('http://pflu.evolbio.mpg.de/bio_data/11859'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11848'),
# ...

# %%
parser.entry_point
# Out:
# rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900')

# %%
graph = get_graph(parser.entry_point)

# %%
for terms in graph:
    pprint(terms)
# Out:
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900'),
#  rdflib.term.URIRef('http://pflu.evolbio.mpg.de/cv/lookup/local/codon_start'),
#  rdflib.term.Literal('1'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900'),
#  rdflib.term.URIRef('http://pflu.evolbio.mpg.de/cv/lookup/local/frame'),
#  rdflib.term.Literal('0'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900'),
#  rdflib.term.URIRef('http://pflu.evolbio.mpg.de/cv/lookup/local/protein_id'),
#  rdflib.term.Literal('CAY46341.1'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#type'),
#  rdflib.term.Literal('CDS'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900'),
#  rdflib.term.URIRef('http://edamontology.org/data_0842'),
#  rdflib.term.Literal('CDS:PFLU_0056-0'))
# ...

# %%
import getpass

# %%
for ns in parser.graph.namespace_manager.namespaces():
    pprint(ns)
# Out:
# ('brick', rdflib.term.URIRef('https://brickschema.org/schema/Brick#'))
# ('csvw', rdflib.term.URIRef('http://www.w3.org/ns/csvw#'))
# ('dc', rdflib.term.URIRef('http://purl.org/dc/elements/1.1/'))
# ('dcat', rdflib.term.URIRef('http://www.w3.org/ns/dcat#'))
# ('dcmitype', rdflib.term.URIRef('http://purl.org/dc/dcmitype/'))
# ('cdterms', rdflib.term.URIRef('http://purl.org/dc/terms/'))
# ('dcam', rdflib.term.URIRef('http://purl.org/dc/dcam/'))
# ('doap', rdflib.term.URIRef('http://usefulinc.com/ns/doap#'))
# ('foaf', rdflib.term.URIRef('http://xmlns.com/foaf/0.1/'))
# ('geo', rdflib.term.URIRef('http://www.opengis.net/ont/geosparql#'))
# ('odrl', rdflib.term.URIRef('http://www.w3.org/ns/odrl/2/'))
# ('org', rdflib.term.URIRef('http://www.w3.org/ns/org#'))
# ('prof', rdflib.term.URIRef('http://www.w3.org/ns/dx/prof/'))
# ('prov', rdflib.term.URIRef('http://www.w3.org/ns/prov#'))
# ('qb', rdflib.term.URIRef('http://purl.org/linked-data/cube#'))
# ...

# %%
parser.graph.bind('pflutranscript', Namespace('http://pflu.evolbio.mpg.de/web-services/content/v0.1/Transcript/'))

# %%
parser.parse()

# %%
len(parser.graph)
# Out:
# 529

# %%
for term in parser.graph:
    print(term)
# Out:
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/CDS/11900/database+cross+reference'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Cross Reference'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/Organism/1'), rdflib.term.URIRef('https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=common_name'), rdflib.term.Literal('Pseudomonas fluorescens SBW25'))
# (rdflib.term.URIRef('http://pflu.evolbio.mpg.de/web-services/content/v0.1/Organism/1/database+cross+reference'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Cross Reference'))
# ...

# %% [markdown]
# ## Add namespaces

# %%
parser.graph.serialize('11900.ttl')
# Out:
# <Graph identifier=N4a64e7686b4b409191aab24ee6cd4cdc (<class 'rdflib.graph.Graph'>)>

# %%
from rdflib import namespace
from rdflib.namespace import *

# %%
namespace
# Out:
# typing.List

# %%
NamespaceManager(parser.graph, bind_namespaces='rdflib')

# %%
parser.graph.serialize('11900.ttl')
# Out:
# <Graph identifier=N34da199703ff4d48a33ea0665dbb01b2 (<class 'rdflib.graph.Graph'>)>
